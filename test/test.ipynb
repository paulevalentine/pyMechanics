# %%
# %load_ext autoreload
# %autoreload 2
from structural_functions import A_rectangle, I_rectangle, ss_max_deflection
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
b = 50 ; h = 200
a = A_rectangle(b,h)
i = I_rectangle(b,h)
Em = 11000
Gm = 8000
w = 5
span = 3000
ss_max_deflection(w, span, i, a, Em, Gm)
# Out:
# Calculate the area of a rectangle (mm2)
# Eq(A, b*h)
# Eq(A, 1.0e+4)
# Calculate the moment of area of a rectangle (mm4)
# Eq(I, b*h**3/12)
# Eq(I, 3.33e+7)
# Calculate the max bending deflection (mm):
# Eq(delta_m, 5*l**4*w/(384*E_m*I))
# Eq(delta_m, 14.4)
# Calculate the max shear deflection (mm):
# Eq(delta_v, 0.15*l**2*w/(A*G_m))
# Eq(delta_v, 0.0844)
# Calculate the total deflection (mm):
# Eq(delta_t, delta_m + delta_v)
# Eq(delta_t, 14.5)
# 14.5
